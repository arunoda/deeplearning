# %% [markdown]
# # Inference
#
# Basically, this is using the trained model for predictions.<br/>
# To do this, we don't need a GPU. We can do this in a CPU.
#
# Basically, that's the idea.
# You train a model on a powerful device, then put that model in a less powerful model.<br/>
# May be in the edge(Rasberry Pi) or inside a Web app.

# %%
from fastai2.vision.all import *
from utils import *

# %%
## Let's load the model
learn = load_learner("cats-and-dogs.pkl")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-530cd33c3875> in <module>
#       1 ## Let's load the model
# ----> 2 learn = load_learner("cats-and-dogs.pkl")
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/fastai2/learner.py in load_learner(fname, cpu)
#     522 def load_learner(fname, cpu=True):
#     523     "Load a `Learner` object in `fname`, optionally putting it on the `cpu`"
# --> 524     res = torch.load(fname, map_location='cpu' if cpu else None)
#     525     if hasattr(res, 'to_fp32'): res = res.to_fp32()
#     526     if cpu: res.dls.cpu()
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     527             with _open_zipfile_reader(f) as opened_zipfile:
#     528                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
# --> 529         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     530
#     531
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/serialization.py in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#     700     unpickler = pickle_module.Unpickler(f, **pickle_load_args)
#     701     unpickler.persistent_load = persistent_load
# --> 702     result = unpickler.load()
#     703
#     704     deserialized_storage_keys = pickle_module.load(f, **pickle_load_args)
#
# AttributeError: Can't get attribute 'cat_or_dog' on <module '__main__'>

# %% [markdown]
# **Hmm. It failed why?**
#
# Oh we need to get our `cat_or_dog` function.

# %%
def cat_or_dog(p):
    if p.name[0].isupper():
        return 'cat'
    else:
        return 'dog'

# %%
# Let's try to load it again
learn = load_learner('cats-and-dogs.pkl')

# %% [markdown]
# ## Let's Predict

# %%
uploader = widgets.FileUpload()

# %%
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
im_uploaded = PILImage.create(uploader.data[0])
show_image(im_uploaded)

# %%
learn.predict(im_uploaded)
# Out:
# ('cat', tensor(0), tensor([1.0000e+00, 3.2547e-15]))

# %%
uploader
# Out:
# FileUpload(value={'Screenshot 2020-04-29 at 00.04.49.png': {'metadata': {'name': 'Screenshot 2020-04-29 at 00.…

# %%
im_uploaded = PILImage.create(uploader.data[0])
show_image(im_uploaded)

# %%
learn.predict(im_uploaded)
# Out:
# ('dog', tensor(1), tensor([1.6171e-05, 9.9998e-01]))
